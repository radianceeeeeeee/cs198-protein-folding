# %%
# !pip install ipynb
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\Petter Xymone\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from ipynb.fs.full.dijkstra import shortest_path, euclidean_distance_3d
import ipynb.fs.full.matrix_generator as matrix_gen
import numpy as np

# %%
m = matrix_gen.generate_matrix()

# %%
plt = matrix_gen.generate_2d_map(m)

# %%
x = (0, 24)
y = (17, 2)

print(x, m[x[0]][x[1]])
print(y, m[y[0]][y[1]])

dst, path = shortest_path(m, x, y, euclidean_distance_3d)
print(dst)
print(path, sep=" -> ")
# Out:
# (0, 24) 0.2572875184048874
# (17, 2) 0.44629765106542507
# ...

# %%
matrix_gen.generate_2d_map_with_path(m, path)

# %%
m[0, 23]
# Out:
# 0.013677277634508433
